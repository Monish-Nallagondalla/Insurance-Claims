# %% [markdown]
# # Confustion Matrics using Insurnace Claims Data

# %%
#Import package and functions
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load the Insurance dataset
insdata = pd.read_csv(r"C:\Users\MONISH\OneDrive\Desktop\Git_upload\Machine learning Projects\Insurance Claims\insurance_claims.csv")

# %%
insdata.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17/10/2014           OH
# 1                 228   42         342868       27/06/2006           IN
# 2                 134   29         687698       06/09/2000           OH
# 3                 256   41         227811       25/05/1990           IL
# 4                 228   44         367455       06/06/2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
display(insdata)
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17/10/2014           OH
# 1                   228   42         342868       27/06/2006           IN
# 2                   134   29         687698       06/09/2000           OH
# 3                   256   41         227811       25/05/1990           IL
# 4                   228   44         367455       06/06/2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16/07/1991           OH
# 996                 285   41         186934       05/01/2014           IL
# 997                 130   34         918516       17/02/2003           OH
# 998                 458   62         533940       18/11/2011           IL
# 999                 456   60         556080       11/11/1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
insdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
display(insdata.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
#Count the occurances of fraud and no fraud and print them
cnt = insdata['fraud_reported'].value_counts()
cnt
# Out:
# N    753
# Y    247
# Name: fraud_reported, dtype: int64

# %%
insdata['fraud_reported'].value_counts().plot(kind='bar',rot=1)
# Out:
# <AxesSubplot:>

# %%
insdata['incident_state'].value_counts()
# Out:
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: incident_state, dtype: int64

# %%
insdata['incident_state'].value_counts().plot(kind='bar',rot=3)
# Out:
# <AxesSubplot:>

# %%
#We should definitely delete some so that our pipeline can more easily handle the data when it feeds it into our
#machine Learning algorithms.
del insdata['policy_number']
del insdata['policy_bind_date']
del insdata['insured_zip']
del insdata['_c39']

# %%
insdata.head()
# Out:
#    months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                 328   48           OH    250/500               1000
# 1                 228   42           IN    250/500               2000
# 2                 134   29           OH    100/300               2000
# 3                 256   41           IL    250/500               2000
# 4                 228   44           IL   500/1000               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 4                1583.91         6000000        MALE               Associate
#
#   insured_occupation  ... witnesses police_report_available  \
# ...

# %%
Xdf = insdata.loc[:,'months_as_customer':'auto_year']
Ydf = insdata['fraud_reported']
Ydf = Ydf.replace("Y",1)
Ydf = Ydf.replace("N",0)

# %%
insdata.head()
# Out:
#    months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                 328   48           OH    250/500               1000
# 1                 228   42           IN    250/500               2000
# 2                 134   29           OH    100/300               2000
# 3                 256   41           IL    250/500               2000
# 4                 228   44           IL   500/1000               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 4                1583.91         6000000        MALE               Associate
#
#   insured_occupation  ... witnesses police_report_available  \
# ...

# %%
Xdf
# Out:
#      months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                   328   48           OH    250/500               1000
# 1                   228   42           IN    250/500               2000
# 2                   134   29           OH    100/300               2000
# 3                   256   41           IL    250/500               2000
# 4                   228   44           IL   500/1000               1000
# ..                  ...  ...          ...        ...                ...
# 995                   3   38           OH   500/1000               1000
# 996                 285   41           IL    100/300               1000
# 997                 130   34           OH    250/500                500
# 998                 458   62           IL   500/1000               2000
# 999                 456   60           OH    250/500               1000
#
#      policy_annual_premium  umbrella_limit insured_sex  \
# ...

# %%
Ydf
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: fraud_reported, Length: 1000, dtype: int64

# %%
#Most of the columns are categorical which will not allow us to run machine learning algorithms. so let's encode these data
#by using the 'get_dummies' method from the pandas library.
convDF = pd.get_dummies(Xdf)
convDF.shape
# Out:
# (1000, 1221)

# %%
convDF.head()
# Out:
#    months_as_customer  age  policy_deductable  policy_annual_premium  \
# 0                 328   48               1000                1406.91
# 1                 228   42               2000                1197.22
# 2                 134   29               2000                1413.14
# 3                 256   41               2000                1415.74
# 4                 228   44               1000                1583.91
#
#    umbrella_limit  capital-gains  capital-loss  incident_hour_of_the_day  \
# 0               0          53300             0                         5
# 1         5000000              0             0                         8
# 2         5000000          35100             0                         7
# 3         6000000          48900        -62400                         5
# 4         6000000          66000        -46000                        20
#
#    number_of_vehicles_involved  bodily_injuries  ...  auto_model_Pathfinder  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(convDF, Ydf, test_size=0.2, random_state=30)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
#Fit the model
logReg = LogisticRegression()
logReg.fit(X_train,y_train)
# Out:
# C:\Users\MONISH\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#Evaluate the model
y_pred = logReg.predict(X_test)

# %%
import sklearn.metrics as metrics
print(metrics.confusion_matrix(y_test,y_pred))
# Out:
# [[153   1]
#  [ 46   0]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.99      0.87       154
#            1       0.00      0.00      0.00        46
#
#     accuracy                           0.77       200
#    macro avg       0.38      0.50      0.43       200
# weighted avg       0.59      0.77      0.67       200
